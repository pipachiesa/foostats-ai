# %%
# !pip install ultralytics

# %% [markdown]
# # Get Dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="BYCSiaiR4lIRTZLIPXjs")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# 619.56s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: roboflow in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (1.2.13)
# Requirement already satisfied: certifi in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from roboflow) (2025.11.12)
# Requirement already satisfied: idna==3.7 in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from roboflow) (3.10.7)
# Requirement already satisfied: numpy>=1.18.5 in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from roboflow) (2.3.5)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from roboflow) (12.0.0)
# Requirement already satisfied: pillow-avif-plugin<2 in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from roboflow) (1.5.5)
# Requirement already satisfied: python-dateutil in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from roboflow) (1.2.1)
# Requirement already satisfied: requests in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from roboflow) (2.32.5)
# Requirement already satisfied: six in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from roboflow) (4.67.3)
# Requirement already satisfied: PyYAML>=5.3.1 in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests-toolbelt in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: pi-heif<2 in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from matplotlib->roboflow) (4.60.1)
# Requirement already satisfied: packaging>=20.0 in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=3 in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from matplotlib->roboflow) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/felipechiesa/.pyenv/versions/3.12.3/lib/python3.12/site-packages (from requests->roboflow) (3.4.4)
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-players-detection-1 to yolov5pytorch::   0%|          | 0/148663 [00:00<?, ?it/s]0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Downloading Dataset Version Zip in football-players-detection-1 to yolov5pytorch:: 100%|██████████| 148663/148663 [00:07<00:00, 18965.62it/s]
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:00<00:00, 6525.62it/s]

# %%
dataset.location
# Out:
# '/Users/felipechiesa/Desktop/foostats_ai/training/football-players-detection-1'

# %%
import shutil
shutil.move(
    'football-players-detection-1/train',
    'football-players-detection-1/train'
)

shutil.move(
    'football-players-detection-1/test',
    'football-players-detection-1/test'
)

shutil.move(
    'football-players-detection-1/valid',
    'football-players-detection-1/valid'
)

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov5m.pt data{dataset.location}/data.yaml epochs=100 imgsz=640
